# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('Datasets/latest_responses_dominantVAK.csv')

df
# Out:
#       Gender Level of Study  \
# 0     Female   Postgraduate
# 1     Female   Postgraduate
# 2     Female   Postgraduate
# 3     Female   Postgraduate
# 4     Female  Undergraduate
# ...      ...            ...
# 1046  Female  Undergraduate
# 1047  Female  Undergraduate
# 1048    Male  Undergraduate
# 1049  Female  Undergraduate
# 1050  Female  Undergraduate
#
#                        Preferred Communication Platform  \
# 0                                              Whatsapp
# 1     Email, University eLearning Chat Room, Whatsap...
# 2                                       Email, Whatsapp
# 3                                              Whatsapp
# 4       Email, University eLearning Chat Room, Whatsapp
# ...                                                 ...
# 1046                          Email, Whatsapp, Telegram
# 1047                          Email, Whatsapp, Telegram
# 1048           University eLearning Chat Room, Whatsapp
# ...

# %%
# !pip install seaborn

# %% [markdown]
# ## Count the number of preferred online assessment based on VAK
# - For EDA purpose

# %%
# Count occurrences of '1' for each learning object per Dominant VAK
online_assessment = df.iloc[:, 3:16]
online_assessment.head()
# Out:
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                         Not Really
# 3                                           Somewhat
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                           Somewhat
# 3                                          Very Much
# ...

# %%
# Replace 'Very Much' with 1 and other values with 0
online_assessment_binary = online_assessment.applymap(lambda x: 1 if x == 'Very Much' else 0)

# Group by Dominant_VAK and sum the counts
counts = online_assessment_binary.groupby(df['Dominant_VAK']).sum().reset_index()

# Display the counts
counts
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13264\32116189.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   online_assessment_binary = online_assessment.applymap(lambda x: 1 if x == 'Very Much' else 0)
#   Dominant_VAK  6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0     Auditory                                                133
# 1  Kinesthetic                                                126
# 2       Visual                                                278
#
#    6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                                 54
# 1                                                 55
# 2                                                123
#
#    6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                                 63
# 1                                                 32
# ...

# %%
# Save into a new csv
counts.to_csv('Datasets/counts_preferred_assessment.csv', index=False)

# %% [markdown]
# ## Explode lists into rows

# %%
# columns_to_explode = [
# #     'Preferred learning mode', 
# #                       'Preferred Social Media Platform', 
#                       'Preferred Communication Platform']

# # Split and explode lists in each column
# for column in columns_to_explode:
#     df[column] = df[column].str.split(', ')
#     df = df.explode(column)

# # Reset index after exploding
# df = df.reset_index(drop=True)

# df.head()

# %%
df['Preferred Communication Platform'] = df['Preferred Communication Platform'].str.split(', ')
df = df.explode('Preferred Communication Platform')

# Reset index after exploding
df = df.reset_index(drop=True)

df.head()
# Out:
#    Gender Level of Study Preferred Communication Platform  \
# 0  Female   Postgraduate                         Whatsapp
# 1  Female   Postgraduate                            Email
# 2  Female   Postgraduate   University eLearning Chat Room
# 3  Female   Postgraduate                         Whatsapp
# 4  Female   Postgraduate                             Call
#
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# ...

# %%
# distinct_values = df['Preferred learning mode'].unique()

# for value in distinct_values:
#     print(value)

# %%
# distinct_values = df['Preferred Social Media Platform'].unique()

# for value in distinct_values:
#     print(value)

# %%
# # Mapping different representations to a standardized value
# standardized_values = {
#     'YouTube ': 'Youtube'
# }

# # Replace values in the 'Institutions' column with the standardized values
# df['Preferred Social Media Platform'] = df['Preferred Social Media Platform'].replace(standardized_values)
# df.head()

# %%
# distinct_values = df['Preferred Social Media Platform'].unique()

# for value in distinct_values:
#     print(value)

# %% [markdown]
# ### Group the minority responses

# %%
distinct_values = df['Preferred Communication Platform'].unique()

for value in distinct_values:
    print(value)
# Out:
# Whatsapp
# Email
# University eLearning Chat Room
# Call
# Telegram
# Others
# Teams or Google Meet
# Microsoft Teams
# Discord

# %%
# Mapping different representations to a standardized value
standardized_values = {
    'Teams or Google Meet': 'Others',
    'Microsoft Teams': 'Others',
    'Discord': 'Others'
}

# Replace values in the 'Institutions' column with the standardized values
df['Preferred Communication Platform'] = df['Preferred Communication Platform'].replace(standardized_values)
df.head()
# Out:
#    Gender Level of Study Preferred Communication Platform  \
# 0  Female   Postgraduate                         Whatsapp
# 1  Female   Postgraduate                            Email
# 2  Female   Postgraduate   University eLearning Chat Room
# 3  Female   Postgraduate                         Whatsapp
# 4  Female   Postgraduate                             Call
#
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# ...

# %%
distinct_values = df['Preferred Communication Platform'].unique()

for value in distinct_values:
    print(value)
# Out:
# Whatsapp
# Email
# University eLearning Chat Room
# Call
# Telegram
# Others

# %% [markdown]
# ## Encode data

# %% [markdown]
# ### 1. Ordinal Encoding for Categorical Data

# %%
# Define the custom ordinal encoding mapping
gender_mapping = {
    'Female': 0,
    'Male': 1
}

study_level_mapping = {
    'Certificate/Diploma': 1,
    'Undergraduate': 2,
    'Postgraduate': 3
}

# income_mapping = {
#     'Less than RM 4,849': 1,
#     'RM 4,850 - RM10,959': 2,
#     'More than RM10,960': 3
# }

preference_mapping = {
    'Not at All': 0,
    'Not Really': 0,
    'Undecided': 0,
    'Somewhat': 0,
    'Very Much': 1
}

vak_mapping = {
    'Visual': 1,
    'Auditory': 2,
    'Kinesthetic': 3
}

# %%
df['Gender'] = df['Gender'].map(gender_mapping)
df['Level of Study'] = df['Level of Study'].map(study_level_mapping)
df['Dominant_VAK'] = df['Dominant_VAK'].map(vak_mapping)

# %%
# Check for null values in the DataFrame
null_values = df.isnull().sum()

# Display the null values
print("Null Values in the DataFrame:")
print(null_values)
# Out:
# Null Values in the DataFrame:
# Gender                                                                                      0
# Level of Study                                                                              0
# Preferred Communication Platform                                                            0
# 6. Online Instructional Strategies/Assessment [Demonstration]                               0
# 6. Online Instructional Strategies/Assessment [Digital Lab Experiments]                     0
# 6. Online Instructional Strategies/Assessment [Forum]                                       0
# 6. Online Instructional Strategies/Assessment [Case Study]                                  0
# 6. Online Instructional Strategies/Assessment [Concept Mapping]                             0
# 6. Online Instructional Strategies/Assessment [Real Time Online Exam]                       0
# 6. Online Instructional Strategies/Assessment [Individual Project/Assignment]               0
# ...

# %%
# # Drop rows with null values
# df = df.dropna()

# # Check for null values in the DataFrame
# null_values = df.isnull().sum()

# # Display the null values
# print("Null Values in the DataFrame:")
# print(null_values)

# %%
# Extract online assessment columns to encode
online_asssessment_columns = df.iloc[:, 3:16]
online_asssessment_columns.head()
# Out:
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                           Somewhat
# 3                                           Somewhat
# ...

# %%
for column in online_asssessment_columns.columns:
    df[column] = df[column].map(preference_mapping)
    
df.head()
# Out:
#    Gender  Level of Study Preferred Communication Platform  \
# 0       0               3                         Whatsapp
# 1       0               3                            Email
# 2       0               3   University eLearning Chat Room
# 3       0               3                         Whatsapp
# 4       0               3                             Call
#
#    6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# ...

# %% [markdown]
# ### 2. One-hot encoding

# %%
# One-hot encoding for multiple columns
columns_to_encode = [
#     'Preferred learning mode', 
#     'Preferred Social Media Platform',
    'Preferred Communication Platform']

df = pd.get_dummies(df, columns=columns_to_encode, prefix=columns_to_encode)

df.head()
# Out:
#    Gender  Level of Study  \
# 0       0               3
# 1       0               3
# 2       0               3
# 3       0               3
# 4       0               3
#
#    6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                                  0
# ...

# %%
# Extract vak_questions columns to encode
vak_ques_columns = df.iloc[:, 15:45]
vak_ques_columns.head()
# Out:
#   1. When operating new equipment for the first time I prefer to  \
# 0           Have a go and learn by "trial and error"
# 1                              Read the instructions
# 2                              Read the instructions
# 3                              Read the instructions
# 4                              Read the instructions
#
#   2. When seeking travel directions I 3. When cooking a new dish I  \
# 0                       Look at a map              Follow a recipe
# 1                       Look at a map              Follow a recipe
# 2                       Look at a map              Follow a recipe
# 3                       Look at a map              Follow a recipe
# 4                       Look at a map              Follow a recipe
#
#       4. To teach someone something I     5. I tend to say 6. I tend to say  \
# 0                    Explain verbally  I know how you feel       Let me try
# ...

# %%
df = pd.get_dummies(df, columns=vak_ques_columns.columns, prefix=vak_ques_columns.columns)

df.head()
# Out:
#    Gender  Level of Study  \
# 0       0               3
# 1       0               3
# 2       0               3
# 3       0               3
# 4       0               3
#
#    6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                                  0
# ...

# %% [markdown]
# ## Remove rows where user did not select their preferred assessment method

# %%
columns_to_check = [
    '6. Online Instructional Strategies/Assessment [Demonstration]',
    '6. Online Instructional Strategies/Assessment [Digital Lab Experiments]',
    '6. Online Instructional Strategies/Assessment [Forum]',
    '6. Online Instructional Strategies/Assessment [Case Study]',
    '6. Online Instructional Strategies/Assessment [Concept Mapping]',
    '6. Online Instructional Strategies/Assessment [Real Time Online Exam]',
    '6. Online Instructional Strategies/Assessment [Individual Project/Assignment]',
    '6. Online Instructional Strategies/Assessment [Group Project/Assignment]',
    '6. Online Instructional Strategies/Assessment [Online Quiz/Test - MCQ]',
    '6. Online Instructional Strategies/Assessment [Online Quiz/Test - Essay]',
    '6. Online Instructional Strategies/Assessment [Online Quiz/Test - Open Book]',
    '6. Online Instructional Strategies/Assessment [Peer Review Assessment Live Presentation]',
    '6. Online Instructional Strategies/Assessment [Recorded Presentation]'
]

# Check if all values in the specified columns are equal to 0
rows_to_drop = df[df[columns_to_check].eq(0).all(axis=1)]

# Drop the rows
df = df.drop(rows_to_drop.index)

df.head()
# Out:
#    Gender  Level of Study  \
# 1       0               3
# 2       0               3
# 3       0               3
# 4       0               3
# 5       0               3
#
#    6. Online Instructional Strategies/Assessment [Demonstration]  \
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#    6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#    6. Online Instructional Strategies/Assessment [Forum]  \
# 1                                                  0
# ...

# %% [markdown]
# ## Save into a new csv file

# %%
# Save into a new csv
df.to_csv('Datasets/latest_responses_encoded.csv', index=False)
