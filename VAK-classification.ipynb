# %%
import pandas as pd

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('Datasets/responses_cleaned.csv')

df.head()
# Out:
#    Gender Level of Study    Household Income  \
# 0  Female   Postgraduate  Less than RM 4,849
# 1  Female   Postgraduate  Less than RM 4,849
# 2  Female   Postgraduate  More than RM10,960
# 3  Female   Postgraduate  More than RM10,960
# 4  Female  Undergraduate  Less than RM 4,849
#
#                              Preferred learning mode  \
# 0  Face to Face, Synchronous Online Learning (Rea...
# 1                                       Face to Face
# 2  Face to Face, Asynchronous Online Learning (On...
# 3                                       Face to Face
# 4                                       Face to Face
#
#   Preferred Social Media Platform  \
# 0                       Instagram
# 1    Facebook, Twitter, Instagram
# 2               Facebook, Youtube
# 3                        Facebook
# 4    Facebook, Instagram, Youtube
#
#                     Preferred Communication Platform  \
# 0                                           Whatsapp
# 1  Email, University eLearning Chat Room, Whatsap...
# 2                                    Email, Whatsapp
# 3                                           Whatsapp
# 4    Email, University eLearning Chat Room, Whatsapp
#
#                      Difficulties in Online Learning  \
# 0              Technical Issues, Quality of Material
# 1                       Technical Issues, Engagement
# 2  Adaptability, Technical Issues, Time Managemen...
# 3                                   Technical Issues
# 4    Adaptability, Technical Issues, Self-Motivation
#
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                         Not Really
# 3                                           Somewhat
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Forum]  ...  \
# 0                                           Somewhat     ...
# 1                                           Somewhat     ...
# 2                                           Somewhat     ...
# 3                                          Very Much     ...
# 4                                          Undecided     ...
#
#                     21. When I revise for an exam, I  \
# 0  I talk over my notes, to myself or to other pe...
# 1  I talk over my notes, to myself or to other pe...
# 2                       Write lots of revision notes
# 3                       Write lots of revision notes
# 4                       Write lots of revision notes
#
#   22. When explaining something to someone, I tend to  \
# 0  Encourage them to try and talk them through th...
# 1  Explain to them in different ways until they u...
# 2  Encourage them to try and talk them through th...
# 3  Explain to them in different ways until they u...
# 4  Encourage them to try and talk them through th...
#
#                            23. My main interests are  \
# 0   Photography or watching films or people watching
# 1  Physical/sports activities or fine wines, fine...
# 2  Listening to music or listening to the radio o...
# 3  Listening to music or listening to the radio o...
# 4  Physical/sports activities or fine wines, fine...
#
#           24. Most of my free time is spent  \
# 0                       Watching television
# 1  Doing physical activity or making things
# 2                       Watching television
# 3  Doing physical activity or making things
# 4  Doing physical activity or making things
#
#         25. When I first contact a new person 26. I first notice how people  \
# 0             I talk to them on the telephone                Stand and move
# 1            I arrange a face to face meeting               Sound and speak
# 2            I arrange a face to face meeting                Look and dress
# 3             I talk to them on the telephone               Sound and speak
# 4  I try to get together to share an activity                Look and dress
#
#                               27. If I am very angry  \
# 0         I stomp about, slam doors and throw things
# 1  I keep replaying in my mind what it is that ha...
# 2  I keep replaying in my mind what it is that ha...
# 3  I keep replaying in my mind what it is that ha...
# 4            I shout lots and tell people how I feel
#
#   28. I find it easiest to remember  \
# 0                             Faces
# 1                Things I have done
# 2                Things I have done
# 3                Things I have done
# 4                Things I have done
#
#   29. I think I can tell someone is lying because  \
# 0                       They avoid looking at you
# 1                       The vibes I get from them
# 2                       The vibes I get from them
# 3                       The vibes I get from them
# 4                       The vibes I get from them
#
#   30. When I'm meeting with an old friend
# 0  I say "it's great to hear your voice!"
# 1          I say "it's great to see you!"
# 2        I give them a hug or a handshake
# 3          I say "it's great to see you!"
# 4        I give them a hug or a handshake
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Extract only the VAK Questions columns

# %%
# Extract columns 43 to 73
vak_df = df.iloc[:, 23:53]

vak_df.head()
# Out:
#   1. When operating new equipment for the first time I prefer to  \
# 0           Have a go and learn by "trial and error"
# 1                              Read the instructions
# 2                              Read the instructions
# 3               Listen to or ask for an explaination
# 4                              Read the instructions
#
#   2. When seeking travel directions I 3. When cooking a new dish I  \
# 0                       Look at a map              Follow a recipe
# 1                       Look at a map              Follow a recipe
# 2           Ask for spoken directions              Follow a recipe
# 3           Ask for spoken directions              Follow a recipe
# 4                       Look at a map              Follow a recipe
#
#       4. To teach someone something I            5. I tend to say  \
# 0                    Explain verbally         I know how you feel
# 1  Demonstrate and let them have a go         I know how you feel
# 2  Demonstrate and let them have a go         I see what you mean
# 3                    Explain verbally  I hear what you are saying
# 4  Demonstrate and let them have a go         I know how you feel
#
#   6. I tend to say      7. I tend to say  \
# 0       Let me try  Listen to me explain
# 1       Let me try     Watch how I do it
# 2          Tell me  Listen to me explain
# 3       Let me try  Listen to me explain
# 4       Let me try         You have a go
#
#          8. Complaining about faulty goods I tend to  \
# 0  Go back to the store, or send the faulty item ...
# 1  Go back to the store, or send the faulty item ...
# 2  Go back to the store, or send the faulty item ...
# 3                                     Write a letter
# 4                                     Write a letter
#
#    9. I prefer these leisure activities 10. When shopping generally I tend to  \
# 0  Physical activities or making things                       Look and decide
# 1  Physical activities or making things                       Look and decide
# 2                  Museums or galleries                       Look and decide
# 3                 Music or conversation                       Look and decide
# 4  Physical activities or making things                       Look and decide
#
#    ...                   21. When I revise for an exam, I  \
# 0  ...  I talk over my notes, to myself or to other pe...
# 1  ...  I talk over my notes, to myself or to other pe...
# 2  ...                       Write lots of revision notes
# 3  ...                       Write lots of revision notes
# 4  ...                       Write lots of revision notes
#
#   22. When explaining something to someone, I tend to  \
# 0  Encourage them to try and talk them through th...
# 1  Explain to them in different ways until they u...
# 2  Encourage them to try and talk them through th...
# 3  Explain to them in different ways until they u...
# 4  Encourage them to try and talk them through th...
#
#                            23. My main interests are  \
# 0   Photography or watching films or people watching
# 1  Physical/sports activities or fine wines, fine...
# 2  Listening to music or listening to the radio o...
# 3  Listening to music or listening to the radio o...
# 4  Physical/sports activities or fine wines, fine...
#
#           24. Most of my free time is spent  \
# 0                       Watching television
# 1  Doing physical activity or making things
# 2                       Watching television
# 3  Doing physical activity or making things
# 4  Doing physical activity or making things
#
#         25. When I first contact a new person 26. I first notice how people  \
# 0             I talk to them on the telephone                Stand and move
# 1            I arrange a face to face meeting               Sound and speak
# 2            I arrange a face to face meeting                Look and dress
# 3             I talk to them on the telephone               Sound and speak
# 4  I try to get together to share an activity                Look and dress
#
#                               27. If I am very angry  \
# 0         I stomp about, slam doors and throw things
# 1  I keep replaying in my mind what it is that ha...
# 2  I keep replaying in my mind what it is that ha...
# 3  I keep replaying in my mind what it is that ha...
# 4            I shout lots and tell people how I feel
#
#   28. I find it easiest to remember  \
# 0                             Faces
# 1                Things I have done
# 2                Things I have done
# 3                Things I have done
# 4                Things I have done
#
#   29. I think I can tell someone is lying because  \
# 0                       They avoid looking at you
# 1                       The vibes I get from them
# 2                       The vibes I get from them
# 3                       The vibes I get from them
# 4                       The vibes I get from them
#
#   30. When I'm meeting with an old friend
# 0  I say "it's great to hear your voice!"
# 1          I say "it's great to see you!"
# 2        I give them a hug or a handshake
# 3          I say "it's great to see you!"
# 4        I give them a hug or a handshake
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Define the answers for each V-A-K

# %%
# Define answers options
visual_keywords = ["Read the instructions", 
                   "Look at a map", 
                   "Follow a recipe", 
                   "Write Instructions",
                   "I see what you mean",
                   "Show me",
                   "Watch how I do it",
                   "Write a letter",
                   "Museums or galleries",
                   "Look and decide",
                   "Read the brochures",
                   "Read the reviews",
                   "I watch what the teacher is doing",
                   "I imagine what the food will look like",
                   "I sing along to the lyrics (in my head or out loud)",
                   "Focus on the words or pictures in front of me",
                   "Writing notes or keeping printed details",
                   "Looking at something",
                   "Visualize the worst case scenarios",
                   "How they look",
                   "Write lots of revision notes",
                   "Show them what I mean",
                   "Photography or watching films or people watching",
                   "Watching television",
                   "I arrange a face to face meeting",
                   "Look and dress",
                   "I keep replaying in my mind what it is that has upset me",
                   "Faces",
                   "They avoid looking at you",
                   "I say \"it's great to see you!\"",
                  ]

auditory_keywords = ["Listen to or ask for an explaination", 
                     "Ask for spoken directions", 
                     "Call a friend for explaination",
                     "Explain verbally",
                     "I hear what you are saying",
                     "Tell me",
                     "Listen to me explain",
                     "Phone",
                     "Music or conversation",
                     "Discuss with shop staff",
                     "Listen to recommendations",
                     "Discuss with friends",
                     "I talk through with the teacher exactly what I am supposed to do",
                     "I talk through the options in my head",
                     "I listen to the lyrics and the beats",
                     "Discuss the problem and possible solutions in my head",
                     "Saying them aloud or repeating words and key points in my head",
                     "Being spoken to",
                     "Talk over in my head what worries me most",
                     "What they say to me",
                     "I talk over my notes, to myself or to other people",
                     "Explain to them in different ways until they understand",
                     "Listening to music or listening to the radio or talking to friends",
                     "Talking to friends",
                     "I talk to them on the telephone",
                     "Sound and speak",
                     "I shout lots and tell people how I feel",
                     "Names",
                     "Their voice changes",
                     "I say \"it's great to hear your voice!\""
                    ]

kinesthetic_keywords = ["Have a go and learn by \"trial and error\"", 
                        "Follow my nose or maybe use a compass", 
                        "Follow my instinct, tasting as I cook",
                        "Demonstrate and let them have a go",
                        "I know how you feel",
                        "Let me try",
                        "You have a go",
                        "Go back to the store, or send the faulty item to the head office",
                        "Physical activities or making things",
                        "Try on, handle or test",
                        "Imagine the experience",
                        "Test-drive what you fancy",
                        "I like to give it a try and work it out as I go along by doing it",
                        "I imagine what  the food will taste like", #double spacing here
                        "I move in time with the music",
                        "Move around a lot, fiddle with pens and pencils and touch unrelated things",
                        "Doing and practicing the activity or imagining it being done",
                        "Doing something",
                        "Can't sit still, fiddle and move around constantly",
                        "How they make me",
                        "Imagine making the movement or creating the formula",
                        "Encourage them to try and talk them through the idea as they try",
                        "Physical/sports activities or fine wines, fine foods or dancing",
                        "Doing physical activity or making things",
                        "I try to get together to share an activity",
                        "Stand and move",
                        "I stomp about, slam doors and throw things",
                        "Things I have done",
                        "The vibes I get from them",
                        "I give them a hug or a handshake"
                       ]

# %% [markdown]
# ## Determine the dominant VAK learning style for each respondent

# %%
# Initialize a list to store the dominant VAK learning style for each respondent
dominant_learning_style = []

# Iterate through the rows (each row represents a respondent)
for index, row in vak_df.iterrows():
    visual_count = 0
    auditory_count = 0
    kinesthetic_count = 0

    # Iterate through the columns (each column is a question)
    for column in vak_df.columns:
        response = row[column].lower()
        
        # compare answer with the response
        for answer in visual_keywords:
            if answer.lower() in response:
                visual_count += 1

        for answer in auditory_keywords:
            if answer.lower() in response:
                auditory_count += 1

        for answer in kinesthetic_keywords:
            if answer.lower() in response:
                kinesthetic_count += 1

    # Determine the dominant VAK preference for this respondent
    preferences = {
        "Visual": visual_count,
        "Auditory": auditory_count,
        "Kinesthetic": kinesthetic_count
    }

    dominant_preference = max(preferences, key=preferences.get)
    dominant_learning_style.append(dominant_preference)

# Add the list of dominant learning style as a new column in the DataFrame
vak_df['Dominant_VAK'] = dominant_learning_style

vak_df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4904\2361988830.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vak_df['Dominant_VAK'] = dominant_learning_style
#   1. When operating new equipment for the first time I prefer to  \
# 0           Have a go and learn by "trial and error"
# 1                              Read the instructions
# 2                              Read the instructions
# 3               Listen to or ask for an explaination
# 4                              Read the instructions
#
#   2. When seeking travel directions I 3. When cooking a new dish I  \
# 0                       Look at a map              Follow a recipe
# 1                       Look at a map              Follow a recipe
# 2           Ask for spoken directions              Follow a recipe
# 3           Ask for spoken directions              Follow a recipe
# 4                       Look at a map              Follow a recipe
#
#       4. To teach someone something I            5. I tend to say  \
# 0                    Explain verbally         I know how you feel
# 1  Demonstrate and let them have a go         I know how you feel
# 2  Demonstrate and let them have a go         I see what you mean
# 3                    Explain verbally  I hear what you are saying
# 4  Demonstrate and let them have a go         I know how you feel
#
#   6. I tend to say      7. I tend to say  \
# 0       Let me try  Listen to me explain
# 1       Let me try     Watch how I do it
# 2          Tell me  Listen to me explain
# 3       Let me try  Listen to me explain
# 4       Let me try         You have a go
#
#          8. Complaining about faulty goods I tend to  \
# 0  Go back to the store, or send the faulty item ...
# 1  Go back to the store, or send the faulty item ...
# 2  Go back to the store, or send the faulty item ...
# 3                                     Write a letter
# 4                                     Write a letter
#
#    9. I prefer these leisure activities 10. When shopping generally I tend to  \
# 0  Physical activities or making things                       Look and decide
# 1  Physical activities or making things                       Look and decide
# 2                  Museums or galleries                       Look and decide
# 3                 Music or conversation                       Look and decide
# 4  Physical activities or making things                       Look and decide
#
#    ... 22. When explaining something to someone, I tend to  \
# 0  ...  Encourage them to try and talk them through th...
# 1  ...  Explain to them in different ways until they u...
# 2  ...  Encourage them to try and talk them through th...
# 3  ...  Explain to them in different ways until they u...
# 4  ...  Encourage them to try and talk them through th...
#
#                            23. My main interests are  \
# 0   Photography or watching films or people watching
# 1  Physical/sports activities or fine wines, fine...
# 2  Listening to music or listening to the radio o...
# 3  Listening to music or listening to the radio o...
# 4  Physical/sports activities or fine wines, fine...
#
#           24. Most of my free time is spent  \
# 0                       Watching television
# 1  Doing physical activity or making things
# 2                       Watching television
# 3  Doing physical activity or making things
# 4  Doing physical activity or making things
#
#         25. When I first contact a new person 26. I first notice how people  \
# 0             I talk to them on the telephone                Stand and move
# 1            I arrange a face to face meeting               Sound and speak
# 2            I arrange a face to face meeting                Look and dress
# 3             I talk to them on the telephone               Sound and speak
# 4  I try to get together to share an activity                Look and dress
#
#                               27. If I am very angry  \
# 0         I stomp about, slam doors and throw things
# 1  I keep replaying in my mind what it is that ha...
# 2  I keep replaying in my mind what it is that ha...
# 3  I keep replaying in my mind what it is that ha...
# 4            I shout lots and tell people how I feel
#
#   28. I find it easiest to remember  \
# 0                             Faces
# 1                Things I have done
# 2                Things I have done
# 3                Things I have done
# 4                Things I have done
#
#   29. I think I can tell someone is lying because  \
# 0                       They avoid looking at you
# 1                       The vibes I get from them
# 2                       The vibes I get from them
# 3                       The vibes I get from them
# 4                       The vibes I get from them
#
#   30. When I'm meeting with an old friend Dominant_VAK
# 0  I say "it's great to hear your voice!"       Visual
# 1          I say "it's great to see you!"       Visual
# 2        I give them a hug or a handshake       Visual
# 3          I say "it's great to see you!"     Auditory
# 4        I give them a hug or a handshake  Kinesthetic
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Save dataframe o new csv with the VAK dominant column

# %%
# Extract columns 43 to 73
new_df = df.iloc[:, :20]

new_df.head()
# Out:
#    Gender Level of Study    Household Income  \
# 0  Female   Postgraduate  Less than RM 4,849
# 1  Female   Postgraduate  Less than RM 4,849
# 2  Female   Postgraduate  More than RM10,960
# 3  Female   Postgraduate  More than RM10,960
# 4  Female  Undergraduate  Less than RM 4,849
#
#                              Preferred learning mode  \
# 0  Face to Face, Synchronous Online Learning (Rea...
# 1                                       Face to Face
# 2  Face to Face, Asynchronous Online Learning (On...
# 3                                       Face to Face
# 4                                       Face to Face
#
#   Preferred Social Media Platform  \
# 0                       Instagram
# 1    Facebook, Twitter, Instagram
# 2               Facebook, Youtube
# 3                        Facebook
# 4    Facebook, Instagram, Youtube
#
#                     Preferred Communication Platform  \
# 0                                           Whatsapp
# 1  Email, University eLearning Chat Room, Whatsap...
# 2                                    Email, Whatsapp
# 3                                           Whatsapp
# 4    Email, University eLearning Chat Room, Whatsapp
#
#                      Difficulties in Online Learning  \
# 0              Technical Issues, Quality of Material
# 1                       Technical Issues, Engagement
# 2  Adaptability, Technical Issues, Time Managemen...
# 3                                   Technical Issues
# 4    Adaptability, Technical Issues, Self-Motivation
#
#   6. Online Instructional Strategies/Assessment [Demonstration]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Digital Lab Experiments]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                         Not Really
# 3                                           Somewhat
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Forum]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                           Somewhat
# 3                                          Very Much
# 4                                          Undecided
#
#   6. Online Instructional Strategies/Assessment [Case Study]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                         Not Really
# 3                                           Somewhat
# 4                                          Undecided
#
#   6. Online Instructional Strategies/Assessment [Concept Mapping]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Undecided
# 3                                           Somewhat
# 4                                          Undecided
#
#   6. Online Instructional Strategies/Assessment [Real Time Online Exam]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                          Very Much
# 3                                           Somewhat
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Individual Project/Assignment]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                           Somewhat
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Group Project/Assignment]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                          Very Much
# 3                                          Very Much
# 4                                          Very Much
#
#   6. Online Instructional Strategies/Assessment [Online Quiz/Test - MCQ]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                          Very Much
# 4                                           Somewhat
#
#   6. Online Instructional Strategies/Assessment [Online Quiz/Test - Essay]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                          Very Much
# 4                                           Somewhat
#
#   6. Online Instructional Strategies/Assessment [Online Quiz/Test - Open Book]  \
# 0                                           Somewhat
# 1                                          Very Much
# 2                                           Somewhat
# 3                                           Somewhat
# 4                                           Somewhat
#
#   6. Online Instructional Strategies/Assessment [Peer Review Assessment Live Presentation]  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                          Very Much
# 3                                           Somewhat
# 4                                           Somewhat
#
#   6. Online Instructional Strategies/Assessment [Recorded Presentation]
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                          Undecided
# 3                                          Very Much
# 4                                          Very Much

# %%
# Extract the Dominant_VAK column to merge with df
column_to_merge = vak_df['Dominant_VAK']

# Combine column_to_merge and the extracted column (df) column-wise (axis=1)
combined = pd.concat([new_df, column_to_merge], axis=1)

# Save into a new csv
combined.to_csv('Datasets/responses_dominantVAK.csv', index=False)
